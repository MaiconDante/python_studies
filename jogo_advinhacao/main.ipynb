# %% [markdown]
# # **JOGO ADVINHAÇÃO DE NÚMERO**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import random

print("*********************************")
print("Bem vindo ao jogo de Adivinhação!")
print("*********************************")

number_random = random.randint(1, 100)

while True:
    try:
        attempt = int(input("Digite o número que desejas adivinhar (1 a 100): "))
        print(f"O número que você digitou é: {attempt}")
        break
    except:
        print("Digite um número válido.")

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import random

print("*********************************")
print("Bem vindo ao jogo de Adivinhação!")
print("*********************************")

number_random = random.randint(1, 100)

while True:
    try:
        attempt = int(input("Digite o número que desejas adivinhar (1 a 100): "))
        print(f"O número que você digitou é: {attempt}")

        if attempt == number_random:
            print("PARABÉNS VOCÊ ACERTOU O NÚMERO !!!")
            break
        elif attempt < number_random:
            print("TENTE UM NÚMERO MAIOR !!!")
        else:
            print("TENTE UM NÚMERO MENOR !!!")
    except:
        print("Digite um número válido.")

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import random

print("*********************************")
print("Bem vindo ao jogo de Adivinhação!")
print("*********************************")

number_random = random.randint(1, 100)
tentativas = 0

while True:
    try:
        attempt = int(input("Digite o número que desejas adivinhar (1 a 100): "))
        print(f"O número que você digitou é: {attempt}")
        tentativas += 1

        if attempt == number_random:
            print("PARABÉNS VOCÊ ACERTOU O NÚMERO !!!")
            break
        elif attempt < number_random:
            print("TENTE UM NÚMERO MAIOR !!!")
        else:
            print("TENTE UM NÚMERO MENOR !!!")
    except:
        print("Digite um número válido.")

print(f"Você acertou em {tentativas} tentativas")
if tentativas <= 5:
  print("EXCELENTE !!!")
elif tentativas <= 10:
  print("BOM !!!")
else:
  print("Você conseguiu, mas pode MELHORAR !!!")

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import random
from art import tprint

jogar_novamente = 's'
while jogar_novamente == 's':
    print("*********************************")
    print("Bem vindo ao jogo de Adivinhação!")
    print("*********************************")

    number_random = random.randint(1, 100)
    tentativas = 1

    while True:
        try:
            tprint(f"{tentativas} -  TENTATIVAS")
            attempt = int(input("Digite o número que desejas adivinhar (1 a 100): "))
            print(f"O número que você digitou é: {attempt}")
            tentativas += 1

            if attempt == number_random:
                print("PARABÉNS VOCÊ ACERTOU O NÚMERO !!!")
                break
            elif attempt < number_random:
                print("TENTE UM NÚMERO MAIOR !!!")
            else:
                print("TENTE UM NÚMERO MENOR !!!")
        except ValueError:
            print("Digite um número inteiro válido.")

    print(f"\nVocê acertou em {tentativas} tentativas")
    if tentativas <= 5:
        print("EXCELENTE !!!")
    elif tentativas <= 10:
        print("BOM !!!")
    else:
        print("Você conseguiu, mas pode MELHORAR !!!")

    jogar_novamente = input("\nDesejas jogar novamente? (s/n): ").lower().strip()

print("\nObrigado por jogar! Até a próxima! 👋")
